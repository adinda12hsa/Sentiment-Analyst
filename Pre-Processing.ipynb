# %%
# !pip install sastrawi
# Out:
# Requirement already satisfied: sastrawi in /usr/local/lib/python3.12/dist-packages (1.0.1)

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.corpus import stopwords
import re

# %% [markdown]
# 1. Load Data

# %%
data = pd.read_csv('/content/drive/MyDrive/Data Science /Penambangan Data (Data Mining)/UAS Analisis Sentimen/youtube-comments-penyerangan as terhadap penangkapan presiden maduro')
data.head()
# Out:
#                    Date                   user  \
# 0  2026-01-09T12:11:50Z             @aldi07007
# 1  2026-01-09T11:18:23Z                @Redit9
# 2  2026-01-09T10:50:01Z           @theguns1199
# 3  2026-01-09T09:59:59Z  @christianproprey9687
# 4  2026-01-09T05:14:54Z          @Darmawan-n9f
#
#                                              comment  like
# 0                     Cuma berani sama negara kecil😂     0
# 1  Rakyat venezuela sudah muak sama presidennya y...     0
# 2  Amerika pikir2 mau nyerang indonesia karna di ...     0
# 3                                Ini tindakan invasi     0
# 4  Apakah presiden Venezuela akan di hukum mati, ...     0

# %%
data = data[['Date', 'comment', 'like']]
data.dropna(subset=['comment'], inplace=True)
data.head()
# Out:
#                    Date                                            comment  \
# 0  2026-01-09T12:11:50Z                     Cuma berani sama negara kecil😂
# 1  2026-01-09T11:18:23Z  Rakyat venezuela sudah muak sama presidennya y...
# 2  2026-01-09T10:50:01Z  Amerika pikir2 mau nyerang indonesia karna di ...
# 3  2026-01-09T09:59:59Z                                Ini tindakan invasi
# 4  2026-01-09T05:14:54Z  Apakah presiden Venezuela akan di hukum mati, ...
#
#    like
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %% [markdown]
# 2. Case folding

# %%
data['casefolding'] = data['comment'].str.lower()
data.head()
# Out:
#                    Date                                            comment  \
# 0  2026-01-09T12:11:50Z                     Cuma berani sama negara kecil😂
# 1  2026-01-09T11:18:23Z  Rakyat venezuela sudah muak sama presidennya y...
# 2  2026-01-09T10:50:01Z  Amerika pikir2 mau nyerang indonesia karna di ...
# 3  2026-01-09T09:59:59Z                                Ini tindakan invasi
# 4  2026-01-09T05:14:54Z  Apakah presiden Venezuela akan di hukum mati, ...
#
#    like                                        casefolding
# 0     0                     cuma berani sama negara kecil😂
# 1     0  rakyat venezuela sudah muak sama presidennya y...
# 2     0  amerika pikir2 mau nyerang indonesia karna di ...
# 3     0                                ini tindakan invasi
# 4     0  apakah presiden venezuela akan di hukum mati, ...

# %% [markdown]
# Cleaning

# %%
data['cleaning'] = data['casefolding'].apply(
    lambda x: re.sub(r'[^a-zA-Z0-9]', ' ', x)
)
data.head()
# Out:
#                    Date                                            comment  \
# 0  2026-01-09T12:11:50Z                     Cuma berani sama negara kecil😂
# 1  2026-01-09T11:18:23Z  Rakyat venezuela sudah muak sama presidennya y...
# 2  2026-01-09T10:50:01Z  Amerika pikir2 mau nyerang indonesia karna di ...
# 3  2026-01-09T09:59:59Z                                Ini tindakan invasi
# 4  2026-01-09T05:14:54Z  Apakah presiden Venezuela akan di hukum mati, ...
#
#    like                                        casefolding  \
# 0     0                     cuma berani sama negara kecil😂
# 1     0  rakyat venezuela sudah muak sama presidennya y...
# 2     0  amerika pikir2 mau nyerang indonesia karna di ...
# 3     0                                ini tindakan invasi
# 4     0  apakah presiden venezuela akan di hukum mati, ...
#
#                                             cleaning
# 0                     cuma berani sama negara kecil
# 1  rakyat venezuela sudah muak sama presidennya y...
# 2  amerika pikir2 mau nyerang indonesia karna di ...
# 3                                ini tindakan invasi
# 4  apakah presiden venezuela akan di hukum mati  ...

# %% [markdown]
# 3. Tokenisasi

# %%
nltk.download('punkt_tab')
data['tokenisasi'] = data['cleaning'].apply(word_tokenize)
data.head()
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
#                    Date                                            comment  \
# 0  2026-01-09T12:11:50Z                     Cuma berani sama negara kecil😂
# 1  2026-01-09T11:18:23Z  Rakyat venezuela sudah muak sama presidennya y...
# 2  2026-01-09T10:50:01Z  Amerika pikir2 mau nyerang indonesia karna di ...
# 3  2026-01-09T09:59:59Z                                Ini tindakan invasi
# 4  2026-01-09T05:14:54Z  Apakah presiden Venezuela akan di hukum mati, ...
#
#    like                                        casefolding  \
# 0     0                     cuma berani sama negara kecil😂
# 1     0  rakyat venezuela sudah muak sama presidennya y...
# 2     0  amerika pikir2 mau nyerang indonesia karna di ...
# 3     0                                ini tindakan invasi
# 4     0  apakah presiden venezuela akan di hukum mati, ...
#
#                                             cleaning  \
# 0                     cuma berani sama negara kecil
# 1  rakyat venezuela sudah muak sama presidennya y...
# 2  amerika pikir2 mau nyerang indonesia karna di ...
# 3                                ini tindakan invasi
# 4  apakah presiden venezuela akan di hukum mati  ...
#
#                                           tokenisasi
# 0                [cuma, berani, sama, negara, kecil]
# 1  [rakyat, venezuela, sudah, muak, sama, preside...
# 2  [amerika, pikir2, mau, nyerang, indonesia, kar...
# 3                            [ini, tindakan, invasi]
# 4  [apakah, presiden, venezuela, akan, di, hukum,...

# %% [markdown]
# Normalisasi kata tidak baku

# %%
normalisasi_dict = {
    'gk': 'tidak',
    'ga': 'tidak',
    'nggak': 'tidak',
    'tdk': 'tidak',
    'bgt': 'banget',
    'pdhl': 'padahal',
    'aja': 'saja',
    'krn': 'karena',
    'yg': 'yang'
}

def normalisasi(tokens):
    return [normalisasi_dict.get(word, word) for word in tokens]

data['tokenisasi'] = data['tokenisasi'].apply(normalisasi)

# %% [markdown]
# 4. Stop Word

# %%
stop_words = set(stopwords.words('indonesian'))

custom_stopwords = {
    'nya', 'lah', 'kah', 'pun', 'dong', 'deh', 'kok',
    'sih', 'tuh', 'ya', 'nih', 'eh'
}

stop_words = stop_words.union(custom_stopwords)

data['stopword'] = data['tokenisasi'].apply(
    lambda x: [word for word in x if word not in stop_words]
)

# %% [markdown]
# menghapus kata dengan panjang sangat dikit (1 sampai 2 huruf)

# %%
data['stopword'] = data['stopword'].apply(
    lambda x: [word for word in x if len(word) > 2]
)

# %% [markdown]
# 5. Stemming

# %%
factory = StemmerFactory()
stemmer = factory.create_stemmer()

data['stemming'] = data['stopword'].apply(
    lambda x: [stemmer.stem(word) for word in x]
)
data.head()
# Out:
#                    Date                                            comment  \
# 0  2026-01-09T12:11:50Z                     Cuma berani sama negara kecil😂
# 1  2026-01-09T11:18:23Z  Rakyat venezuela sudah muak sama presidennya y...
# 2  2026-01-09T10:50:01Z  Amerika pikir2 mau nyerang indonesia karna di ...
# 3  2026-01-09T09:59:59Z                                Ini tindakan invasi
# 4  2026-01-09T05:14:54Z  Apakah presiden Venezuela akan di hukum mati, ...
#
#    like                                        casefolding  \
# 0     0                     cuma berani sama negara kecil😂
# 1     0  rakyat venezuela sudah muak sama presidennya y...
# 2     0  amerika pikir2 mau nyerang indonesia karna di ...
# 3     0                                ini tindakan invasi
# 4     0  apakah presiden venezuela akan di hukum mati, ...
#
#                                             cleaning  \
# 0                     cuma berani sama negara kecil
# 1  rakyat venezuela sudah muak sama presidennya y...
# 2  amerika pikir2 mau nyerang indonesia karna di ...
# 3                                ini tindakan invasi
# 4  apakah presiden venezuela akan di hukum mati  ...
#
#                                           tokenisasi  \
# 0                [cuma, berani, sama, negara, kecil]
# 1  [rakyat, venezuela, sudah, muak, sama, preside...
# 2  [amerika, pikir2, mau, nyerang, indonesia, kar...
# 3                            [ini, tindakan, invasi]
# 4  [apakah, presiden, venezuela, akan, di, hukum,...
#
#                                             stopword  \
# 0                                   [berani, negara]
# 1  [rakyat, venezuela, muak, presidennya, korup, ...
# 2  [amerika, pikir2, nyerang, indonesia, karna, t...
# 3                                 [tindakan, invasi]
# 4  [presiden, venezuela, hukum, mati, halny, pres...
#
#                                             stemming
# 0                                   [berani, negara]
# 1  [rakyat, venezuela, muak, presiden, korup, neg...
# 2  [amerika, pikir2, nyerang, indonesia, karna, t...
# 3                                   [tindak, invasi]
# 4  [presiden, venezuela, hukum, mati, halny, pres...

# %%
data['text_clean'] = data['stemming'].apply(lambda x: ' '.join(x))
data_clean = data[['Date', 'comment', 'text_clean', 'like']]
data_clean.head()
# Out:
#                    Date                                            comment  \
# 0  2026-01-09T12:11:50Z                     Cuma berani sama negara kecil😂
# 1  2026-01-09T11:18:23Z  Rakyat venezuela sudah muak sama presidennya y...
# 2  2026-01-09T10:50:01Z  Amerika pikir2 mau nyerang indonesia karna di ...
# 3  2026-01-09T09:59:59Z                                Ini tindakan invasi
# 4  2026-01-09T05:14:54Z  Apakah presiden Venezuela akan di hukum mati, ...
#
#                                           text_clean  like
# 0                                      berani negara     0
# 1  rakyat venezuela muak presiden korup negara mi...     0
# 2  amerika pikir2 nyerang indonesia karna tni pas...     0
# 3                                      tindak invasi     0
# 4  presiden venezuela hukum mati halny presiden irak     0

# %% [markdown]
# menghapus data kosong

# %%
data = data[data['text_clean'].str.strip() != '']
data.dropna(subset=['text_clean'], inplace=True)

# %%
data_clean.to_excel('data clean.xlsx', index=False)
